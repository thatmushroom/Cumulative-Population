# %% [markdown]
# # Isochrone analysis - Boulder
# Note that the API key has a 20 call/minute and 500 call/day limit

# %%
# imports
from shapely import Point
from shapely import intersects, difference
from shapely.geometry import shape, mapping
import matplotlib.pylab as plt
import numpy as np
import fiona
import pyproj
from shapely.ops import transform
import requests
import json
import pyproj

# %%
# user inputs 
population_fn = "tl_2020_08_tabblock20/tl_2020_08_tabblock20_26913.shp"
center = Point(476162.44,4429556.22) # utm13N
num_bins = 100 # number of steps between zero and max_dist
request_isochrone = True

# %%
# Isochrone request
# Commented out by default
body = {"locations":[[-105.2792801,40.0158551]],"range":[3600],"attributes":["area"],"interval":360,"range_type":"time", "area_units":"km"}
# Latitude in EPSG:4326
headers = {
    'Accept': 'application/json, application/geo+json, application/gpx+xml, img/png; charset=utf-8',
    'Authorization': '5b3ce3597851110001cf624873ff41f6e4a546c8b32558e1e3c9b986',
    'Content-Type': 'application/json; charset=utf-8'
}
if request_isochrone:
    call = requests.post('https://api.openrouteservice.org/v2/isochrones/driving-car', json=body, headers=headers)

print(call.status_code, call.reason)
print(call.text)
# Out:
# 200 OK
# {"type":"FeatureCollection","metadata":{"attribution":"openrouteservice.org | OpenStreetMap contributors","service":"isochrones","timestamp":1711939917530,"query":{"profile":"driving-car","locations":[[-105.2792801,40.0158551]],"range":[3600.0],"range_type":"time","area_units":"km","attributes":["area"],"interval":360.0},"engine":{"version":"7.1.1","build_date":"2024-01-29T14:41:12Z","graph_date":"2024-03-31T14:14:00Z"}},"bbox":[-105.63075,39.548707,-104.478101,40.516886],"features":[{"type":"Feature","properties":{"group_index":0,"value":360.0,"center":[-105.27926965507234,40.01585711826605],"area":18.95681971},"geometry":{"coordinates":[[[-105.320436,40.012498],[-105.320324,40.012377],[-105.31934,40.011696],[-105.315267,40.01096],[-105.307325,40.009788],[-105.302334,40.012019],[-105.292073,40.006495],[-105.292535,39.999835],[-105.292552,39.999721],[-105.290556,39.997565],[-105.282079,39.994412],[-105.282003,39.994407],[-105.274642,39.995979],[-105.266897,39.995919],[-105.261466,39.993729],[-105.26022,39.993372],[-105.260142,39.993387],[-105.259594,39.993569],[-105.25851,39.995784],[-105.256204,40.00075],[-105.256956,40.009616],[-105.25305,40.012457],[-105.252884,40.012592],[-105.252071,40.013377],[-105.251893,40.014484],[-105.251872,40.014647],[-105.251792,40.023303],[-105.251792,40.023402],[-105.253511,40.025152],[-105.25614,40.027336],[-105.258369,40.029127],[-105.260301,40.030606],[-105.268797,40.038237],[-105.272702,40.040861],[-105.281863,40.042725],[-105.282042,40.04273],[-105.282115,40.04273],[-105.282126,40.04273],[-105.28793,40.037749],[-105.289799,40.032987],[-105.292098,40.029326],[-105.303565,40.028197],[-105.308103,40.028008],[-105.31234,40.028345],[-105.314396,40.028398],[-105.314523,40.028319],[-105.315101,40.026035],[-105.317794,40.014943],[-105.320436,40.012498]]],"type":"Polygon"}},{"type":"Feature","properties":{"group_index":0,"value":720.0,"center":[-105.27926965507234,40.01585711826605],"area":67.36008278},"geometry":{"coordinates":[[[-105.362624,40.004476],[-105.361528,40.002004],[-105.354626,39.999665],[-105.348492,39.999937],[-105.347892,40.000012],[-105.34138,40.004458],[-105.334799,40.005676],[-105.326418,40.007158],[-105.323134,40.008633],[-105.315267,40.01096],[-105.307325,40.009788],[-105.301348,40.001112],[-105.299165,39.998059],[-105.290556,39.997565],[-105.282079,39.994412],[-105.282003,39.994407],[-105.274642,39.995979],[-105.27117,39.988027],[-105.269652,39.984763],[-105.266298,39.979644],[-105.261921,39.97411],[-105.260145,39.972394],[-105.260099,39.972393],[-105.256539,39.974531],[-105.24816,39.974714],[-105.245167,39.97382],[-105.24036,39.970877],[-105.238717,39.970428],[-105.23524,39.971362],[-105.235327,39.971685],[-105.23624,39.973774],[-105.236257,39.976746],[-105.226181,39.980574],[-105.222221,39.978772],[-105.21454,39.975185],[-105.209998,39.973128],[-105.205228,39.971229],[-105.200355,39.969335],[-105.195493,39.967447],[-105.190386,39.965405],[-105.186135,39.963752],[-105.177902,39.960543],[-105.173929,39.958991],[-105.169137,39.957085],[-105.166283,39.95601],[-105.164958,39.959357],[-105.166488,39.959963],[-105.168657,39.960794],[-105.174747,39.963168],[-105.18058,39.965454],[-105.187381,39.968099],[-105.192202,39.97003],[-105.196127,39.971555],[-105.201975,39.973827],[-105.205874,39.975342],[-105.213438,39.984234],[-105.21351,39.987833],[-105.213737,39.987829],[-105.216234,39.987705],[-105.221865,39.988987],[-105.223608,39.999582],[-105.223474,40.00022],[-105.223475,40.000252],[-105.224991,40.00187],[-105.223184,40.012768],[-105.221416,40.014564],[-105.217722,40.021557],[-105.212349,40.027473],[-105.210169,40.030081],[-105.209596,40.031971],[-105.209608,40.032638],[-105.21046,40.033669],[-105.211507,40.033584],[-105.21229,40.033469],[-105.222818,40.033733],[-105.2285,40.041956],[-105.232256,40.049324],[-105.234515,40.052127],[-105.235437,40.051384],[-105.244246,40.049286],[-105.250419,40.052898],[-105.255727,40.054317],[-105.261553,40.058128],[-105.264516,40.059775],[-105.267313 ...

# %%
features_json = json.loads(call.text)['features']
len(features_json)
# Out:
# 10

# %%
# TODO: Build shells and circles out of isochrones
# Transform..."circles"?
circles_4326 = [shape(f['geometry']) for f in features_json]

project = pyproj.Transformer.from_proj(
    pyproj.Proj('epsg:4326'), # source coordinate system
    pyproj.Proj('epsg:32613'), always_xy=True) # destination coordinate system
circles = [transform(project.transform, c) for c in circles_4326 ]


shells = [circles[0]] # Init with inner isochrone

for i in range(len(circles) - 1):
    isochrone_shell = difference(shape(circles[i+1]),shape(circles[i]))
    shells.append(isochrone_shell)

# %%
print(f"lengths: {len(shells)} | {len(circles)}")
# Out:
# lengths: 10 | 10

# %%
# print(circles[0])

# %%
circles[0]
# Out:
# <POLYGON ((472652.642 4429193.544, 472662.152 4429180.08, 472745.86 4429104....>

# %%
circles[1]
# Out:
# <POLYGON ((469048.509 4428316.976, 469140.945 4428042.227, 469729.049 442778...>

# %%
shells[0]
# Out:
# <POLYGON ((472652.642 4429193.544, 472662.152 4429180.08, 472745.86 4429104....>

# %%
shells[1]
# Out:
# <MULTIPOLYGON (((472420.827 4428765.397, 472139.941 4428602.707, 471423.996 ...>

# %%
# make radii, open population shapefile
with fiona.open(population_fn) as col:
    info = [(shape(feat['geometry']), feat['properties']['POP20']) for feat in col]

# %%
population = [np.nan]
cumulative_population = [0]
avg_population_density = [np.nan]
shell_population_density =[np.nan]
total_area = [0]
shell_area = [0]
# circles = [None] + circles
# shells = [None] + shells

for i in range(len(shells)):
# for i, r in enumerate(rs[1:]):

    # buffer point
    # buffered = center.buffer(r)
    buffered = circles[i]
    shell = shells[i]
    
    # # construct the shell between the two radii
    # if i>0:
    #     shell = buffered.difference(circles[-1])
    # else:
    #     shell = buffered
    
    # # store geometry
    # circles.append(buffered)
    # shells.append(shell)
    
    # store areas
    total_area.append(buffered.area)
    shell_area.append(shell.area)
    
    # determine population in this shell
    pop = 0
    for shp, shp_pop in info:
        if intersects(shell, shp):      
            fraction = shell.intersection(shp).area/shp.area     
            pop += fraction*shp_pop
    
    # store populations
    population.append(pop)
    cumulative_population.append(cumulative_population[-1]+pop)
    
    # calculate population density
    avg_population_density.append(cumulative_population[-1]/total_area[-1])
    shell_population_density.append(pop/shell.area)
    
    print(f'SHELL {i}, cumulative pop: {cumulative_population[-1]}')
# Out:
# SHELL 0, cumulative pop: 42779.38820909046
# SHELL 1, cumulative pop: 103104.96331878605
# SHELL 2, cumulative pop: 136855.07063557982
# SHELL 3, cumulative pop: 209118.33772352958
# SHELL 4, cumulative pop: 447156.5140256955
# SHELL 5, cumulative pop: 760236.318569137
# SHELL 6, cumulative pop: 1252765.5232593452
# SHELL 7, cumulative pop: 1702241.1839789464
# SHELL 8, cumulative pop: 2288983.9885595376
# SHELL 9, cumulative pop: 2697858.613662303

# %%
len(avg_population_density)
# Out:
# 11

# %% [markdown]
# ## Plots

# %%
rs = np.linspace(0, 360.*10, num=11)
rs
# Out:
# array([   0.,  360.,  720., 1080., 1440., 1800., 2160., 2520., 2880.,
#        3240., 3600.])

# %%
fig, axes = plt.subplots(figsize=(4,8),ncols=1, nrows=3, dpi=100, layout='constrained')

axes[0].plot(rs/60, population)
axes[0].set_xlabel("Distance from Canyon and Broadway, minutes")
axes[0].set_ylabel("Population at this distance, #")

axes[1].plot(rs/60, cumulative_population)
axes[1].set_xlabel("Distance from Canyon and Broadway, minutes")
axes[1].set_ylabel("Cumulative population, #")

axes[2].plot(rs/60, np.array(avg_population_density)*1e6, label ='To this distance')
axes[2].plot(rs/60, np.array(shell_population_density)*1e6, label="Within this shell")
axes[2].legend(title='Explanation')
axes[2].set_xlabel("Distance from Canyon and Broadway, minutes")
axes[2].set_ylabel("Population density, #/km2")
fig.savefig("summary.png", dpi=300)

# %% [markdown]
# ## Export

# %%
with fiona.open(population_fn) as src:
    driver = src.driver
    crs = src.crs
    
schema = {'geometry': 'Polygon',
 'properties': {'pop': 'float',
                'density': 'float',
}}
# shell density
with fiona.open("shells_60min_boulder.shp", "w", 
                driver=driver, crs=crs, 
                schema=schema) as dst:

    for i in range(len(shells)):
        feat = {'geometry':mapping(shells[i]),
                'properties':{'pop':population[i+1],
                            'density': shell_population_density[i+1]*1e6}}

        dst.write(feat)
        
# selected tracts, write out density
selection = center.buffer(75000)   
with fiona.open("tract_density_60min_boulder.shp", "w", 
                driver=driver, crs=crs, 
                schema=schema) as dst:

    for shp, shp_pop in info:
        if intersects(selection,shp):
            feat = {'geometry':mapping(shp),
                'properties':{'pop':shp_pop,
                            'density': shp_pop/shp.area*1e6}}
            dst.write(feat)
